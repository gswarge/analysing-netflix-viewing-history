# %%
import matplotlib as mlt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import datetime
sns.set()

# %%
my_history = pd.read_csv('me.csv')
wife_history = pd.read_csv('wife.csv')

# %%
my_history['Date'] = pd.to_datetime(my_history['Date'])
my_history['Year'], my_history['Month'] = my_history['Date'].dt.year, my_history['Date'].dt.month_name()
my_history['Day'] = my_history['Date'].dt.day
my_history['Day_of_week'] = my_history['Date'].dt.day_name()
#my_history['Month'] = history['Date'].dt.month_name()

# %%
wife_history['Date'] = pd.to_datetime(wife_history['Date'])
wife_history['Year'], wife_history['Month'] = wife_history['Date'].dt.year, wife_history['Date'].dt.month_name()
wife_history['Day'] = wife_history['Date'].dt.day
wife_history['Day_of_week'] = wife_history['Date'].dt.day_name()

# %%
show_details = my_history.Title.str.split(":",expand=True,n=2)
#show_details
my_history['show_name'] = show_details[0]
my_history['season'] = show_details[1]
my_history['episode_name'] = show_details[2]

# %%
show_details = wife_history.Title.str.split(":",expand=True,n=2)
#show_details
wife_history['show_name'] = show_details[0]
wife_history['season'] = show_details[1]
wife_history['episode_name'] = show_details[2]

# %%
#If the season column is "None" them it is most likely a movie, lets add another column to our dataframe 
#my_history[my_history['season'].isna()]
my_history['show_type'] = my_history.apply(lambda x:'Movie' if pd.isnull(x['season']) else 'TV Show' , axis=1)
my_history
# Out:
#                                                  Title       Date  Year  \
# 0               Disenchantment: Part 2: The Very Thing 2019-11-17  2019
# 1             Disenchantment: Part 2: Stairway to Hell 2019-11-17  2019
# 2    Unnatural Selection: Limited Series: Cut, Past... 2019-11-17  2019
# 3    Inside Bill's Brain: Decoding Bill Gates: Limi... 2019-11-16  2019
# 4    Inside Bill's Brain: Decoding Bill Gates: Limi... 2019-11-16  2019
# 5    Inside Bill's Brain: Decoding Bill Gates: Limi... 2019-11-16  2019
# 6                          Explained: Season 2: Coding 2019-11-16  2019
# 7                         Explained: Season 2: Pirates 2019-11-16  2019
# 8    Patriot Act with Hasan Minhaj: Volume 4: The R... 2019-11-15  2019
# 9    Patriot Act with Hasan Minhaj: Volume 4: Fentanyl 2019-11-15  2019
# 10   Patriot Act with Hasan Minhaj: Volume 5: Menta... 2019-11-15  2019
# 11                               Nikki Glaser: Bangin’ 2019-11-14  2019
# 12             Explained: Season 2: The Future of Meat 2019-11-14  2019
# 13                   Sacred Games: Season 2: Radcliffe 2019-11-11  2019
# 14                      Sacred Games: Season 2: Torino 2019-11-11  2019
# 15                      Sacred Games: Season 2: Azrael 2019-11-11  2019
# 16                     Sacred Games: Season 2: Vikarna 2019-11-11  2019
# 17                       Sacred Games: Season 2: Bardo 2019-11-09  2019
# 18                    Sacred Games: Season 2: Apasmara 2019-11-09  2019
# 19                      Sacred Games: Season 2: Siduri 2019-11-09  2019
# 20                      Sacred Games: Season 2: Matsya 2019-11-08  2019
# 21                 Sacred Games: Season 1: Ashwathama  2019-11-08  2019
# 22   Unbreakable Kimmy Schmidt: Season 3: Kimmy Ste... 2019-11-07  2019
# 23              Explained: Season 2: The Next Pandemic 2019-11-07  2019
# 24     The Redeemed and the Dominant: Fittest on Earth 2019-11-06  2019
# 25                                   The Game Changers 2019-10-31  2019
# 26   BoJack Horseman: Season 6: A Quick One, While ... 2019-10-30  2019
# 27   BoJack Horseman: Season 6: The Face of Depression 2019-10-30  2019
# 28   BoJack Horseman: Season 6: The Kidney Stays in... 2019-10-26  2019
# 29   BoJack Horseman: Season 6: A Little Uneven, Is... 2019-10-26  2019
# ..                                                 ...        ...   ...
# 774                       Trapped: Season 1: Episode 1 2018-08-24  2018
# 775           The Office (U.S.): Season 1: Health Care 2018-08-24  2018
# 776         The Office (U.S.): Season 1: Diversity Day 2018-08-24  2018
# 777                 The Office (U.S.): Season 1: Pilot 2018-08-24  2018
# 778                                            Escorts 2018-08-23  2018
# 779                     The Five: Season 1: Episode 10 2018-08-23  2018
# 780                      The Five: Season 1: Episode 9 2018-08-23  2018
# 781                      The Five: Season 1: Episode 8 2018-08-23  2018
# 782                      The Five: Season 1: Episode 7 2018-08-23  2018
# 783                      The Five: Season 1: Episode 6 2018-08-23  2018
# 784                      The Five: Season 1: Episode 5 2018-08-23  2018
# 785                      The Five: Season 1: Episode 4 2018-08-23  2018
# 786                        Explained: Season 1: Tattoo 2018-08-23  2018
# 787                      The Five: Season 1: Episode 3 2018-08-23  2018
# 788                      The Five: Season 1: Episode 2 2018-08-22  2018
# 789                      The Five: Season 1: Episode 1 2018-08-22  2018
# 790               Black Mirror: Season 4: Black Museum 2018-08-22  2018
# 791               House of Cards: Season 4: Chapter 40 2018-08-22  2018
# 792           The Rain: Season 1: Trust Your Instincts 2018-08-22  2018
# 793        The Rain: Season 1: Don't Talk to Strangers 2018-08-22  2018
# 794        The Rain: Season 1: Keep Your Friends Close 2018-08-22  2018
# 795                     The Rain: Season 1: Have Faith 2018-08-22  2018
# 796                   The Rain: Season 1: Trust No One 2018-08-22  2018
# 797                 The Rain: Season 1: Avoid the City 2018-08-22  2018
# 798                  The Rain: Season 1: Stay Together 2018-08-22  2018
# 799                    The Rain: Season 1: Stay Inside 2018-08-21  2018
# 800   Pirates of the Caribbean: Dead Men Tell No Tales 2018-08-21  2018
# 801           Real Life Wife Swap: Season 1: Episode 1 2018-08-21  2018
# 802                                       Lust Stories 2018-08-21  2018
# 803          Explained: Season 1: Can We Live Forever? 2018-08-21  2018
#
#         Month  Day Day_of_week                      show_name  \
# 0    November   17      Sunday                 Disenchantment
# 1    November   17      Sunday                 Disenchantment
# 2    November   17      Sunday            Unnatural Selection
# 3    November   16    Saturday            Inside Bill's Brain
# 4    November   16    Saturday            Inside Bill's Brain
# 5    November   16    Saturday            Inside Bill's Brain
# 6    November   16    Saturday                      Explained
# 7    November   16    Saturday                      Explained
# 8    November   15      Friday  Patriot Act with Hasan Minhaj
# 9    November   15      Friday  Patriot Act with Hasan Minhaj
# 10   November   15      Friday  Patriot Act with Hasan Minhaj
# 11   November   14    Thursday                   Nikki Glaser
# 12   November   14    Thursday                      Explained
# 13   November   11      Monday                   Sacred Games
# 14   November   11      Monday                   Sacred Games
# 15   November   11      Monday                   Sacred Games
# 16   November   11      Monday                   Sacred Games
# 17   November    9    Saturday                   Sacred Games
# 18   November    9    Saturday                   Sacred Games
# 19   November    9    Saturday                   Sacred Games
# 20   November    8      Friday                   Sacred Games
# 21   November    8      Friday                   Sacred Games
# 22   November    7    Thursday      Unbreakable Kimmy Schmidt
# 23   November    7    Thursday                      Explained
# 24   November    6   Wednesday  The Redeemed and the Dominant
# 25    October   31    Thursday              The Game Changers
# 26    October   30   Wednesday                BoJack Horseman
# 27    October   30   Wednesday                BoJack Horseman
# 28    October   26    Saturday                BoJack Horseman
# 29    October   26    Saturday                BoJack Horseman
# ..        ...  ...         ...                            ...
# 774    August   24      Friday                        Trapped
# 775    August   24      Friday              The Office (U.S.)
# 776    August   24      Friday              The Office (U.S.)
# 777    August   24      Friday              The Office (U.S.)
# 778    August   23    Thursday                        Escorts
# 779    August   23    Thursday                       The Five
# 780    August   23    Thursday                       The Five
# 781    August   23    Thursday                       The Five
# 782    August   23    Thursday                       The Five
# 783    August   23    Thursday                       The Five
# 784    August   23    Thursday                       The Five
# 785    August   23    Thursday                       The Five
# 786    August   23    Thursday                      Explained
# 787    August   23    Thursday                       The Five
# 788    August   22   Wednesday                       The Five
# 789    August   22   Wednesday                       The Five
# 790    August   22   Wednesday                   Black Mirror
# 791    August   22   Wednesday                 House of Cards
# 792    August   22   Wednesday                       The Rain
# 793    August   22   Wednesday                       The Rain
# 794    August   22   Wednesday                       The Rain
# 795    August   22   Wednesday                       The Rain
# 796    August   22   Wednesday                       The Rain
# 797    August   22   Wednesday                       The Rain
# 798    August   22   Wednesday                       The Rain
# 799    August   21     Tuesday                       The Rain
# 800    August   21     Tuesday       Pirates of the Caribbean
# 801    August   21     Tuesday            Real Life Wife Swap
# 802    August   21     Tuesday                   Lust Stories
# 803    August   21     Tuesday                      Explained
#
#                       season                      episode_name show_type
# 0                     Part 2                    The Very Thing   TV Show
# 1                     Part 2                  Stairway to Hell   TV Show
# 2             Limited Series                  Cut, Paste, Life   TV Show
# 3        Decoding Bill Gates            Limited Series: Part 3   TV Show
# 4        Decoding Bill Gates            Limited Series: Part 2   TV Show
# 5        Decoding Bill Gates            Limited Series: Part 1   TV Show
# 6                   Season 2                            Coding   TV Show
# 7                   Season 2                           Pirates   TV Show
# 8                   Volume 4          The Real Cost of Cruises   TV Show
# 9                   Volume 4                          Fentanyl   TV Show
# 10                  Volume 5                     Mental Health   TV Show
# 11                   Bangin’                              None   TV Show
# 12                  Season 2                The Future of Meat   TV Show
# 13                  Season 2                         Radcliffe   TV Show
# 14                  Season 2                            Torino   TV Show
# 15                  Season 2                            Azrael   TV Show
# 16                  Season 2
# <b>limit_output extension: Maximum message size of 10000 exceeded with 19125 characters</b>

# %%
wife_history['show_type'] = wife_history.apply(lambda x:'Movie' if pd.isnull(x['season']) else 'TV Show' , axis=1)
wife_history
# Out:
#                                                  Title       Date  Year  \
# 0                                      Erin Brockovich 2019-11-16  2019
# 1    Queer Eye: We're in Japan!: Season 1: Crazy in... 2019-11-15  2019
# 2    Queer Eye: We're in Japan!: Season 1: Japanese... 2019-11-15  2019
# 3                    Rotten: Season 2: The Avocado War 2019-11-12  2019
# 4     Midnight Diner: Tokyo Stories: Season 1: Tan Men 2019-11-12  2019
# 5                              Seth Meyers: Lobby Baby 2019-11-10  2019
# 6                  Wild Wild Country: Season 1: Part 6 2019-11-08  2019
# 7                   The Office (U.S.): Season 1: Pilot 2019-11-08  2019
# 8                  Wild Wild Country: Season 1: Part 3 2019-11-07  2019
# 9                       Our Planet - Behind The Scenes 2019-11-06  2019
# 10                       Our Planet: Season 1: Forests 2019-11-06  2019
# 11                   Our Planet: Season 1: Fresh Water 2019-11-06  2019
# 12                             Planet Earth II: Cities 2019-11-05  2019
# 13                         Planet Earth II: Grasslands 2019-11-05  2019
# 14                 Wild Wild Country: Season 1: Part 5 2019-11-05  2019
# 15                            Planet Earth II: Deserts 2019-11-03  2019
# 16                          Planet Earth II: Mountains 2019-11-03  2019
# 17                 Wild Wild Country: Season 1: Part 4 2019-11-03  2019
# 18                                               Drive 2019-11-03  2019
# 19    Friends: Season 7: The One with Phoebe's Cookies 2019-11-02  2019
# 20       Friends: Season 7: The One with Rachel's Book 2019-11-02  2019
# 21    Friends: Season 7: The One with Monica's Thunder 2019-11-02  2019
# 22   Breakfast, Lunch & Dinner: Season 1: Marrakesh... 2019-11-02  2019
# 23                 Wild Wild Country: Season 1: Part 2 2019-11-02  2019
# 24                 Wild Wild Country: Season 1: Part 1 2019-11-02  2019
# 25   Patriot Act with Hasan Minhaj: Volume 4: The B... 2019-11-02  2019
# 26                                   The Game Changers 2019-11-02  2019
# 27                           Jenny Slate: Stage Fright 2019-10-30  2019
# 28                                      The Laundromat 2019-10-30  2019
# 29   BoJack Horseman: Season 6: A Quick One, While ... 2019-10-30  2019
# ..                                                 ...        ...   ...
# 628       Jane The Virgin: Season 3: Chapter Sixty-One 2018-09-14  2018
# 629           Jane The Virgin: Season 3: Chapter Sixty 2018-09-13  2018
# 630      Jane The Virgin: Season 3: Chapter Fifty-Nine 2018-09-13  2018
# 631     Jane The Virgin: Season 3: Chapter Fifty-Eight 2018-09-13  2018
# 632     Jane The Virgin: Season 3: Chapter Fifty-Seven 2018-09-12  2018
# 633       Jane The Virgin: Season 3: Chapter Fifty-Six 2018-09-12  2018
# 634      Jane The Virgin: Season 3: Chapter Fifty-Five 2018-09-12  2018
# 635      Jane The Virgin: Season 3: Chapter Fifty-Four 2018-09-12  2018
# 636     Jane The Virgin: Season 3: Chapter Fifty-Three 2018-09-06  2018
# 637       Jane The Virgin: Season 3: Chapter Fifty-Two 2018-09-06  2018
# 638       Jane The Virgin: Season 3: Chapter Fifty-One 2018-09-05  2018
# 639           Jane The Virgin: Season 3: Chapter Fifty 2018-09-05  2018
# 640      Jane The Virgin: Season 3: Chapter Forty-Nine 2018-09-04  2018
# 641     Jane The Virgin: Season 3: Chapter Forty-Eight 2018-09-04  2018
# 642     Jane The Virgin: Season 3: Chapter Forty-Seven 2018-09-04  2018
# 643       Jane The Virgin: Season 3: Chapter Forty-Six 2018-09-03  2018
# 644      Jane The Virgin: Season 3: Chapter Forty-Five 2018-09-03  2018
# 645      Jane The Virgin: Season 2: Chapter Forty-Four 2018-09-03  2018
# 646     Jane The Virgin: Season 2: Chapter Forty-Three 2018-09-01  2018
# 647       Jane The Virgin: Season 2: Chapter Forty-One 2018-08-31  2018
# 648           Jane The Virgin: Season 2: Chapter Forty 2018-08-31  2018
# 649     Jane The Virgin: Season 2: Chapter Thirty-Nine 2018-08-31  2018
# 650                     How the Grinch Stole Christmas 2018-08-30  2018
# 651                   Master of None: Season 1: Plan B 2018-08-28  2018
# 652                  To All the Boys I’ve Loved Before 2018-08-28  2018
# 653                                       Carrie Pilby 2018-08-25  2018
# 654                                      The Nice Guys 2018-08-25  2018
# 655                                             Snatch 2018-08-25  2018
# 656                           The Shawshank Redemption 2018-08-25  2018
# 657  Comedians in Cars Getting Coffee: New 2018: Fr... 2018-08-25  2018
#
#          Month  Day Day_of_week                          show_name  \
# 0     November   16    Saturday                    Erin Brockovich
# 1     November   15      Friday                          Queer Eye
# 2     November   15      Friday                          Queer Eye
# 3     November   12     Tuesday                             Rotten
# 4     November   12     Tuesday                     Midnight Diner
# 5     November   10      Sunday                        Seth Meyers
# 6     November    8      Friday                  Wild Wild Country
# 7     November    8      Friday                  The Office (U.S.)
# 8     November    7    Thursday                  Wild Wild Country
# 9     November    6   Wednesday     Our Planet - Behind The Scenes
# 10    November    6   Wednesday                         Our Planet
# 11    November    6   Wednesday                         Our Planet
# 12    November    5     Tuesday                    Planet Earth II
# 13    November    5     Tuesday                    Planet Earth II
# 14    November    5     Tuesday                  Wild Wild Country
# 15    November    3      Sunday                    Planet Earth II
# 16    November    3      Sunday                    Planet Earth II
# 17    November    3      Sunday                  Wild Wild Country
# 18    November    3      Sunday                              Drive
# 19    November    2    Saturday                            Friends
# 20    November    2    Saturday                            Friends
# 21    November    2    Saturday                            Friends
# 22    November    2    Saturday          Breakfast, Lunch & Dinner
# 23    November    2    Saturday                  Wild Wild Country
# 24    November    2    Saturday                  Wild Wild Country
# 25    November    2    Saturday      Patriot Act with Hasan Minhaj
# 26    November    2    Saturday                  The Game Changers
# 27     October   30   Wednesday                        Jenny Slate
# 28     October   30   Wednesday                     The Laundromat
# 29     October   30   Wednesday                    BoJack Horseman
# ..         ...  ...         ...                                ...
# 628  September   14      Friday                    Jane The Virgin
# 629  September   13    Thursday                    Jane The Virgin
# 630  September   13    Thursday                    Jane The Virgin
# 631  September   13    Thursday                    Jane The Virgin
# 632  September   12   Wednesday                    Jane The Virgin
# 633  September   12   Wednesday                    Jane The Virgin
# 634  September   12   Wednesday                    Jane The Virgin
# 635  September   12   Wednesday                    Jane The Virgin
# 636  September    6    Thursday                    Jane The Virgin
# 637  September    6    Thursday                    Jane The Virgin
# 638  September    5   Wednesday                    Jane The Virgin
# 639  September    5   Wednesday                    Jane The Virgin
# 640  September    4     Tuesday                    Jane The Virgin
# 641  September    4     Tuesday                    Jane The Virgin
# 642  September    4     Tuesday                    Jane The Virgin
# 643  September    3      Monday                    Jane The Virgin
# 644  September    3      Monday                    Jane The Virgin
# 645  September    3      Monday                    Jane The Virgin
# 646  September    1    Saturday                    Jane The Virgin
# 647     August   31      Friday                    Jane The Virgin
# 648     August   31      Friday                    Jane The Virgin
# 649     August   31      Friday                    Jane The Virgin
# 650     August   30    Thursday     How the Grinch Stole Christmas
# 651     August   28     Tuesday                     Master of None
# 652     August   28     Tuesday  To All the Boys I’ve Loved Before
# 653     August   25    Saturday                       Carrie Pilby
# 654     August   25    Saturday                      The Nice Guys
# 655     August   25    Saturday                             Snatch
# 656     August   25    Saturday           The Shawshank Redemption
# 657     August   25    Saturday   Comedians in Cars Getting Coffee
#
#                season                                       episode_name  \
# 0                None                                               None
# 1     We're in Japan!                            Season 1: Crazy in Love
# 2     We're in Japan!                         Season 1: Japanese Holiday
# 3            Season 2                                    The Avocado War
# 4       Tokyo Stories                                  Season 1: Tan Men
# 5          Lobby Baby                                               None
# 6            Season 1                                             Part 6
# 7            Season 1                                              Pilot
# 8            Season 1                                             Part 3
# 9                None                                               None
# 10           Season 1                                            Forests
# 11           Season 1                                        Fresh Water
# 12             Citie
# <b>limit_output extension: Maximum message size of 10000 exceeded with 19347 characters</b>

# %%
print('\nSample\n',my_history.sample(5))
# Out:
# Sample
#                                                   Title       Date  Year  \
# 672                                       Jason Bourne 2018-11-05  2018
# 654                 Dogs: Season 1: The Kid with a Dog 2018-11-17  2018
# 371  Bordertown: Season 1: The Lady in the Lake (Pa... 2019-02-13  2019
# 648   Patriot Act with Hasan Minhaj: Volume 1: Supreme 2018-11-20  2018
# 389         BoJack Horseman: Season 5: The Showstopper 2019-02-03  2019
#
#         Month  Day Day_of_week                      show_name     season  \
# 672  November    5      Monday                   Jason Bourne       None
# 654  November   17    Saturday                           Dogs   Season 1
# 371  February   13   Wednesday                     Bordertown   Season 1
# 648  November   20     Tuesday  Patriot Act with Hasan Minhaj   Volume 1
# 389  February    3      Sunday                BoJack Horseman   Season 5
#
#                          episode_name show_type
# 672                              None     Movie
# 654                The Kid with a Dog   TV Show
# 371   The Lady in the Lake (Part One)   TV Show
# 648                           Supreme   TV Show
# 389                   The Showstopper   TV Show

# %%
print('\nSample\n',wife_history.sample(5))
# Out:
# Sample
#                                                   Title       Date  Year  \
# 174     Friends: Season 1: The One with the Stoned Guy 2019-07-29  2019
# 480     Friends from College: Season 1: Second Wedding 2019-02-02  2019
# 498  Conversations with a Killer: The Ted Bundy Tap... 2019-01-25  2019
# 589  Patriot Act with Hasan Minhaj: Volume 1: Saudi... 2018-10-29  2018
# 205     Fargo: Season 3: Who Rules the Land of Denial? 2019-07-04  2019
#
#         Month  Day Day_of_week                      show_name  \
# 174      July   29      Monday                        Friends
# 480  February    2    Saturday           Friends from College
# 498   January   25      Friday    Conversations with a Killer
# 589   October   29      Monday  Patriot Act with Hasan Minhaj
# 205      July    4    Thursday                          Fargo
#
#                    season                     episode_name show_type
# 174              Season 1      The One with the Stoned Guy   TV Show
# 480              Season 1                   Second Wedding   TV Show
# 498   The Ted Bundy Tapes   Limited Series: Handsome Devil   TV Show
# 589              Volume 1                     Saudi Arabia   TV Show
# 205              Season 3    Who Rules the Land of Denial?   TV Show

# %%
#Saving the dataframe as csv
my_history.to_csv('g-history.csv', index=False)
wife_history.to_csv('p-history.csv', index=False)

# %%
#Day of the month - Monthly viewing distribution
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
plt.title("My Viewing Distribution")
ax = sns.distplot(my_history['Day'],bins=31,color="red",hist=True)
plt.subplot(2,1,2)
plt.title("Wife's Viewing Distribution")
ax = sns.distplot(wife_history['Day'],bins=31,hist=True)
plt.savefig('01-viewing-distribution.png')

# %%
#cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
#sns.cubehelix_palette(8)
#sns.color_palette("Blues")
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
ax = sns.barplot(x=my_history["Day_of_week"].value_counts().index, y=my_history["Day_of_week"].value_counts(), palette="cubehelix",alpha=0.7)
plt.title("My Days")
plt.xlabel("Day of the Week")
plt.ylabel("Frequency")

plt.subplot(2,1,2)
ax = sns.barplot(x=wife_history["Day_of_week"].value_counts().index, y=wife_history["Day_of_week"].value_counts(),palette="twilight",alpha=0.7)
plt.title("Wife's Days")
plt.xlabel("Day of the Week")
plt.ylabel("Frequency")
plt.savefig('02-Daywise.png')

# %%
sns.set_style('whitegrid')
by_year = my_history.groupby('Month')['Year'].value_counts().sort_values(ascending=False).reset_index(name='Frequency')
#print(by_year)
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
ax = sns.barplot(x=by_year["Month"], y=by_year["Frequency"], hue=by_year["Year"], palette="twilight",alpha=0.7)
plt.title("Most watched Month for Me")


by_year = wife_history.groupby('Month')['Year'].value_counts().sort_values(ascending=False).reset_index(name='Frequency')
plt.subplot(2,1,2)
ax = sns.barplot(x=by_year["Month"], y=by_year["Frequency"], hue=by_year["Year"], palette="cubehelix_r",alpha=0.7)
plt.title("Most watched Month for Wife")
plt.savefig('03-Monthwise.png')
# Out:
# Text(0.5, 1.0, 'Most watched Month for Wife')

# %%
#when do i watch Movies and TV Shows

show_freq = my_history.groupby('show_type')['Day_of_week'].value_counts().sort_values(ascending=False).reset_index(name='Count')
#show_freq
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
ax = sns.barplot(x=show_freq["Day_of_week"], y=show_freq["Count"], hue=show_freq["show_type"], palette="twilight_r",alpha=0.7)
plt.title("What do i prefer? Movies or Television?")

show_freq = wife_history.groupby('show_type')['Day_of_week'].value_counts().sort_values(ascending=False).reset_index(name='Count')
plt.subplot(2,1,2)
ax = sns.barplot(x=show_freq["Day_of_week"], y=show_freq["Count"], hue=show_freq["show_type"], palette="cubehelix",alpha=0.7)

plt.title("What does wife prefers?  -> Movies or Television?")

plt.savefig('04-MovieVStvshow.png')
# Out:
# Text(0.5, 1.0, 'What does wife prefers?  -> Movies or Television?')

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
ax = sns.barplot(x=my_history['show_name'].sort_values(ascending=True).value_counts().index[:10], 
                 y=my_history["show_name"].sort_values(ascending=True).value_counts()[:10],
                 palette="gist_earth_r")
plt.title("Shows with most time spent")
plt.xlabel("Name of Show")
plt.ylabel("Frequency of Watching")
loc, labels = plt.xticks()
ax.set_xticklabels(labels, rotation=45)
plt.subplot(1,2,2)
ax = sns.barplot(x=wife_history['show_name'].sort_values(ascending=True).value_counts().index[:10], 
                 y=wife_history["show_name"].sort_values(ascending=True).value_counts()[:10],
                 palette="hot_r")
plt.title("Shows my Wife spent most time on")
plt.xlabel("Name of Show")
plt.ylabel("Frequency of Watching")
loc, labels = plt.xticks()
ax.set_xticklabels(labels, rotation=45)
plt.savefig('05-mostwatched.png')


#heatmap.set_xticklabels(labels, rotation=45)

#my_tab = pd.crosstab(index=my_history['show_name'],columns='count')
#(my_tab/my_tab.sum())
#sns.barplot(values_count[:10].index.values, values_count[:10],palette="rocket")
# Out:
# [Text(0, 0, 'Friends'),
#  Text(0, 0, 'BoJack Horseman'),
#  Text(0, 0, 'Jane The Virgin'),
#  Text(0, 0, 'Fargo'),
#  Text(0, 0, "Workin' Moms"),
#  Text(0, 0, 'Sense8'),
#  Text(0, 0, "Marvel's Jessica Jones"),
#  Text(0, 0, 'Master of None'),
#  Text(0, 0, 'Brooklyn Nine-Nine'),
#  Text(0, 0, 'Call My Agent!')]

# %%
#plt.figure(figsize=(15,10))
#sns.set(style="darkgrid")
#sns.lineplot(x=my_history["Month"].value_counts().index, y=my_history["Month"].value_counts())
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)

ax = sns.lineplot(x=my_history["Month"].value_counts().index, y=my_history["Month"].value_counts(), palette="BuGn_r", label="My History")
plt.title("Monthly Viewing Activity")
plt.xlabel("Month")
plt.ylabel("Frequency")
#plt.subplot(2,1,1) # This triggers matplotlib warning
ax = sns.lineplot(x=wife_history["Month"].value_counts().index, y=my_history["Month"].value_counts(), palette="Blues_r", label="Wife's History")
ax.legend()
plt.savefig('06-Monthly-Viewing.png')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
ax = sns.barplot(x=my_history["Month"].value_counts().index, y=my_history["Month"].value_counts(), palette="BuGn_r")
plt.title("Most watched Month for me")
plt.xlabel("Month of the Year")
plt.ylabel("Frequency")

plt.subplot(2,1,2)
ax = sns.barplot(x=wife_history["Month"].value_counts().index, y=wife_history["Month"].value_counts(), palette="Blues_r")
plt.title("Most watched Month for Wife")
plt.xlabel("Month of the Year")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
